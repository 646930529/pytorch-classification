# %%
from torchvision import transforms
from PIL import Image

# %%
path = "transforms.jpeg"
img = Image.open(path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x1E3AFD22488>

# %%
transform = transforms.Compose([
    transforms.ToTensor(), # Convert a ``PIL Image`` or ``numpy.ndarray`` to tensor.
    transforms.ToPILImage() # Convert a tensor or an ndarray to PIL Image.
])

new_img = transform(img)
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x1E39DEBAE88>

# %%
transform = transforms.Compose([
    transforms.CenterCrop([200,500]),
])

new_img = transform(img)
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=500x200 at 0x1E3AFDC2708>

# %%
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5)
])

new_img = transform(img)
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x1E3AFDBD1C8>

# %%
transform = transforms.Compose([
    transforms.RandomRotation([5,35])
])

new_img = transform(img)
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x1E3B0DB9C48>

# %%
transform = transforms.Compose([
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1)
])

new_img = transform(img)
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x1E3B3D586C8>
